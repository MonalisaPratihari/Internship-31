# %%
# Let's now import all the required libraries

import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)
# from trak.in.**

# %%
# Let's first connect to the web driver
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
# Opening the trak website on automated chrome browser
driver.get("https://trak.in/")

# %%
time.sleep(2)

# Extracting the path of Funding deals.
driver.get(driver.find_element(By.XPATH,'//li[@id="menu-item-51510"]/a').get_attribute('href'))

# %%
# Creating the empty list 

Date=[]
Name=[]
Industry_vertical=[]
Sub_vertical=[]
City=[]
Investor_name=[]
Invest_type=[]
Amount=[]

# Scrapping for Date
for i in driver.find_elements(By.XPATH,'//td[@class="column-2"]'):
    Date.append(i.text)

# Scrapping for Name
for i in driver.find_elements(By.XPATH,'//td[@class="column-3"]'):
    Name.append(i.text)

# Scrapping for Industry/vertical    
for i in driver.find_elements(By.XPATH,'//td[@class="column-4"]'):
    Industry_vertical.append(i.text)

# Scrapping for Sub_vertical
for i in driver.find_elements(By.XPATH,'//td[@class="column-5"]'):
    Sub_vertical.append(i.text)

# Scrapping for City    
for i in driver.find_elements(By.XPATH,'//td[@class="column-6"]'):
    City.append(i.text)

# Scrapping for Investor name
for i in driver.find_elements(By.XPATH,'//td[@class="column-7"]'):
    Investor_name.append(i.text)

# Scrapping for Investor type    
for i in driver.find_elements(By.XPATH,'//td[@class="column-8"]'):
    Invest_type.append(i.text)

# Scrapping for Amount
for i in driver.find_elements(By.XPATH,'//td[@class="column-9"]'):
    Amount.append(i.text)

# %%
# Checking for length of each columns
len(Date),len(Name),len(Industry_vertical),len(Sub_vertical),len(City),len(Investor_name),len(Invest_type),len(Amount)
# Out:
# (392, 392, 392, 392, 392, 392, 392, 392)

# %%
# Creating the dataframe for Jan21- Mar21
Funding_deals={'Date':Date,'Name':Name,'Industry/Vertical':Industry_vertical,'Sub-vertical':Sub_vertical,'City':City,'Investor':Investor_name,
        'Investment Type':Invest_type,'Amount(in USD)':Amount}
Funding=pd.DataFrame(data=Funding_deals)
Funding[5:29]
# Out:
#           Date                    Name       Industry/Vertical  \
# 5   04/03/2021               DealShare              E-commerce
# 6   31/03/2021                Uniphore              Technology
# 7   30/03/2021                   Dunzo              E-commerce
# 8   30/03/2021                  BYJU’S                Edu-tech
# 9   23/03/2021             SkilloVilla                Edu-tech
# 10  25/03/2021                CityMall              E-commerce
# 11  26/03/2021                   DotPe                 FinTech
# 12  11/02/2021                Doubtnut                Edu Tech
# 13  22/02/2021                  Zomato             Hospitality
# 14  19/02/2021               Fingerlix             Hospitality
# 15  17/02/2021                   Zolve                 FinTech
# 16  15/02/2021               KreditBee                 Finance
# 17  12/02/2021               Pepperfry              E-commerce
# 18  12/02/2021                 Grofers              E-Commerce
# ...

# %%
driver.close()

# %%
# Let's now import all the required libraries

import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **7. Write a program to scrap all the available details of best gaming laptops from digit.in**

# %%
# Let's first connect to the web driver
driver = webdriver.Chrome(r"chromedriver.exe")

# Opening the digit website on automated chrome browser for best gaming laptops
driver.get('https://www.digit.in/')

time.sleep(2)

# %%
# Clicking on the Top10
driver.find_element(By.XPATH,'/html/body/div[1]/div/div[4]/ul/li[4]/a').click()

# %%
# Clicking on best gaming laptop in India
driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[3]/div[2]/ul/li[25]/a').click()

# %%
# Creating the empty list
Name=[]
Processor=[]
Display=[]
OS=[]
Memory=[]
Graphic_processor=[]
Body=[]
Price=[]

# Scrapping for Name
for i in driver.find_elements(By.XPATH,'//div[@class="TopNumbeHeading"]'):
    Name.append(i.text)

# Scrapping for Processor
for i in driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[5]/td[3]'):
    Processor.append(i.text) 

# Scrapping for Display
for i in driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[4]/td[3]'):
    Display.append(i.text) 

# Scrapping for OS type
for i in driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[3]/td[3]'):
    OS.append(i.text) 

# Scrapping for Memory
for i in driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[6]/td[3]'):
    Memory.append(i.text) 
    
# Scrapping for Graphic_processor
for i in driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]'):
    Graphic_processor.append(i.text) 
    
# Scrapping for Body of the laptop
for i in driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]'):
    Body.append(i.text) 
    
# Scrapping for Price
for i in driver.find_elements(By.XPATH,'//td[@class="smprice"]'):
    if i.text is None :
        Price.append("-")
    else:
        Price.append(i.text)

# %%
# Creating the dataframe
data = list(zip(Name,Processor,Display,OS,Memory,Graphic_processor,Body,Price))
df=pd.DataFrame(data,columns=["Name","Processor","Display","OS","Memory","Graphic_Processor","Body","Price"])
df[:10]
# Out:
#                                                 Name        Processor  \
# 0                           1.\nMSI Titan GT77-12UHS  Windows 11 Home
# 1                               2.\nAlienware X17 R2  Windows 11 Home
# 2          3.\nAcer Predator Triton 500 SE PT516-52s  Windows 11 Home
# 3                        4.\nOmen By HP (16-B1371TX)  Windows 11 Home
# 4  5.\nAcer Predator Helios 300 AN515-45 (NH.QBRSI.0  Windows 11 Home
# 5                     6.\nMSI Delta 15 (A5EFK-083IN)  Windows 11 Home
# 6                        7.\nOmen By HP (16-C0141AX)  Windows 11 Home
# 7              8.\nLenovo Legion 5i Pro (82RF00MGIN)  Windows 11 Home
# 8  9.\nAlienware M15 R5 Ryzen Edition Icc-C780001win  Windows 11 Home
# 9              10.\nLenovo Slim 7 Gen 6 (82K8002JIN)  Windows 11 Home
#
#                                            Display  \
# 0  17.3″ (3840 x 2160) screen, 120 Hz refresh rate
# 1  17.3″ (1920 x 1080) screen, 360 Hz refresh rate
# ...

# %%
driver.close()

# %% [markdown]
# **5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.**

# %%
# Let's first connect to the web driver
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
# Opening the google maps website on automated chrome browser
driver.get('https://www.google.com/maps/')

# %%
# Giving user input for the current location
City = input('Enter City Name : ')
search_bar=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/form/div[2]/div[3]/div/input[1]')
search_bar.send_keys('City')
# Out:
# Enter City Name : Pune

# %%
# Click on the search button
search_button=driver.find_element(By.XPATH,'//div[@class="pzfvzf"]')
search_button.click()

# %%
latitude=driver.current_url.split('/@')[1].split(',')[0]
longtitude=driver.current_url.split('/@')[1].split(',')[1].split(',')[0]
print('Latitude:',latitude,'Longitude:',longtitude)
# Out:
# Latitude: 18.5179101 Longitude: 73.9119477

# %%
driver.close()

# %% [markdown]
# **8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be
# scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.**

# %%
#import libraries
import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

# %%
# Let's first connect to the web driver
driver=webdriver.Chrome('Chromedriver.exe')

# Opening the forbes website on automated chrome browser
url= 'https://www.forbes.com/billionaires/'
driver.get(url)

# %%
# Closing the popup
popup_close=driver.find_element(By.XPATH,"/html/body/div[7]/div/button")
popup_close.click()

# %%
# Extracting the path of arrow to get the desire details of billionaires.

driver.find_element(By.XPATH,'//div[@class="down-arrow"]').click()

# %%
# Creating the empty list
Rank=[]
Name=[]
Net_worth=[]
Age=[]
Citizenship=[]
Source=[]
Industry=[]

# Since there are 15 pages we will scrap the content using range function
start=0
end=15
for page in range(start,end):
# Scrapping Rank data
    rank=driver.find_elements(By.XPATH,"//div[@class='rank']")
    for i in rank:
        Rank.append(i.text)

# Scrapping Name data
    name=driver.find_elements(By.XPATH,"//div[@class='personName']")
    for i in name:
        Name.append(i.text)

# Scrapping Networth data
    networth=driver.find_elements(By.XPATH,"//div[@class='netWorth']/div")
    for i in networth:
        Net_worth.append(i.text)
    
# Scrapping Age data
    age=driver.find_elements(By.XPATH,"//div[@class='age']/div")
    for i in age:
        Age.append(i.text)
    
# Scrapping Citizenship data
    citi=driver.find_elements(By.XPATH,"//div[@class='countryOfCitizenship']")
    for i in citi:
        Citizenship.append(i.text)

# Scrapping Source data
    source=driver.find_elements(By.XPATH,"//div[@class='source-column']/div[1]")
    for i in source:
        Source.append(i.text)
        
# Scrapping Industry data
    industry=driver.find_elements(By.XPATH,"//div[@class='category']/div")
    for i in industry:
        Industry.append(i.text)
    
# To go on the next page scrapping the next button
    try:
        nxt=driver.find_element(By.XPATH,"//button[@class='pagination-btn pagination-btn--next ']").click()
    except:
        NoSuchElementException

# %%
# Creating the Dataframe
Data={'Rank':Rank,'Name':Name,'Net Worth':Net_worth,'Age':Age,
                    'Citizenship':Citizenship,'Source':Source,'Industry':Industry}
Forbes_Billionarie=pd.DataFrame(Data)
Forbes_Billionarie
# Out:
#        Rank                      Name Net Worth Age    Citizenship  \
# 0        1.                 Elon Musk    $219 B  50  United States
# 1        2.                Jeff Bezos    $171 B  58  United States
# 2        3.  Bernard Arnault & family    $158 B  73         France
# 3        4.                Bill Gates    $129 B  66  United States
# 4        5.            Warren Buffett    $118 B  91  United States
# ...     ...                       ...       ...  ..            ...
# 2731  2578.             Zhang Yuqiang      $1 B  66          China
# 2732  2578.                Zhou Ruxin      $1 B  59          China
# 2733  2578.         Wen Zhou & family      $1 B  57          China
# 2734  2578.      Zhou Yifeng & family      $1 B  43          China
# 2735  2578.   Zhuang Kuilong & family      $1 B  59          China
#
#                        Source               Industry
# 0               Tesla, SpaceX             Automotive
# 1                      Amazon             Technology
# ...

# %%
driver.close()

# %% [markdown]
# **4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be
# scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.**

# %%
# Let's first connect to the web driver
driver=webdriver.Chrome('Chromedriver.exe')

# Opening the Flipkart website on automated chrome browser
url= 'https://www.flipkart.com/'
driver.get(url)

# %%
# Closing the popup
popup_close=driver.find_element(By.XPATH,"//button[@class='_2KpZ6l _2doB4z']")
popup_close.click()

# %%
# Entering product category name in search bar
search_bar = driver.find_element(By.XPATH,'//input[@class="_3704LK"]')
search_bar.send_keys('pixel 4A')

# Click on the search button
search_button = driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
search_button.click()

# %%
# Creating the empty list
Brand=[] 
Smartphone_name=[]
Colour=[]
RAM=[] 
Storage=[]
Primary_Camera=[]
Secondary_Camera=[]
Display_Size=[]
Battery_Capacity=[]
Price=[]
Product_url=[]

# Clicking on the product link
product_links=driver.find_elements(By.XPATH,"//a[@class='_1fQZEK']")

# Scrapping the product link
for i in product_links:
    Product_url.append(i.get_attribute('href'))

for i in Product_url:
    driver.get(i)
    driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]').click()    

# Scrapping the Brand name
    try:
        brand=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]').text.split()
        Brand.append(brand[0])
    except:
        Brand.append('-')
        
# Scrapping other details
    a= driver.find_elements(By.XPATH,"//li[@class='_21lJbe']")
    b=driver.find_elements(By.XPATH,"//td[@class='_1hKmbr col col-3-12']")
    for i in range(0,len(b)):
        if b[i].text=='Model Name':
            Smartphone_name.append(a[i].text)      
        if b[i].text=='Color':
            Colour.append(a[i].text)
        if b[i].text=='RAM':
            RAM.append(a[i].text)
        if b[i].text=='Internal Storage':
            Storage.append(a[i].text)
        if b[i].text=='Primary Camera':
            Primary_Camera.append(a[i].text)
        if b[i].text=='Secondary Camera':
            Secondary_Camera.append(a[i].text)                               
        if b[i].text=='Display Size':
            Display_Size.append(a[i].text)
        if b[i].text=='Battery Capacity':
            Battery_Capacity.append(a[i].text)
            
# Scrapping the prices
    try:
        price=driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')
        Price.append(price.text)
    except:
        Price.append('-')

# %%
print(len(Brand),len(Smartphone_name),len(Colour),len(RAM),len(Storage),len(Primary_Camera),len(Secondary_Camera),len(Display_Size),len(Battery_Capacity),len(Price),len(Product_url))
# Out:
# 24 24 24 24 24 24 23 24 24 24 24

# %%
# Creating the dataframe
data={'Brand Name':Brand,'Smartphone Name':Smartphone_name,'Color':Colour,'RAM':RAM,'Storage(ROM)':Storage,'Primary Camera':Primary_Camera,'Secondary Camera':Secondary_Camera,'Display Size':Display_Size,'Battery Capacity':Battery_Capacity,'Price':Price,'Product url':Product_url}
data=pd.DataFrame(data)
data

# %%
# Converting the DataFrame to CSV file.

data.to_csv("C:\\Users\\Shrihan Manit\\OneDrive\\Desktop\\Mona_Intern\\Flipkart.csv",index=False)

# %%
driver.close()

# %% [markdown]
# **Q3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.**

# %%
# let's first connect to the web driver
driver = webdriver.Chrome(r"chromedriver.exe")

# Opening the google images website on automated chrome browser 
driver.get('https://images.google.com/')

time.sleep(2)

# %%
# Entering product name as required in the search bar
search_bar=driver.find_element(By.XPATH,'//input[@class="gLFyf gsfi"]')   
search_bar.send_keys("fruits")

# Searching Item
search_button=driver.find_element(By.XPATH,'//button[@class="Tg7LZd"]').click()

# %%
#10 time we scroll down in order to generate more images on the website
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")
    
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_url = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_url.append(source)
            
            
for i in range(len(img_url)):
    if i > 10:
        break
print("Downloading {0} of {1} images" .format(i, 10))
response= requests.get(img_url[i])
file = open(r"C:\Users\Shrihan Manit\OneDrive\Desktop\Mona_Intern"+str(i)+".jpg", "wb")
file.write(response.content)

# %% [markdown]
# **1. Write a python program which searches all the product under a particular product from www.amazon.in.
# The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search
# for guitars**

# %%
# let's first connect to the web driver
driver = webdriver.Chrome(r"chromedriver.exe")

# Opening the Amazon website on automated chrome browser
driver.get('https://www.amazon.in/')

# %%
# Creating the user input for the product name to be entered
product = input("Enter the product name: ")

# Entering product name as required in the search bar
search_bar = driver.find_element(By.ID,"twotabsearchtextbox").send_keys(product)

# Serching Item
search_button = driver.find_element(By.ID,"nav-search-submit-button").click()
time.sleep(2)
# Out:
# Enter the product name: Guitar

# %%
driver.close()
